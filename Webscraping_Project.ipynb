# %% [markdown]
# <h1>Extracting Stock Data Using a Web Scraping</h1>

# %% [markdown]
# Not all stock data is available via the API in this assignment; you will use web-scraping to obtain financial data. You will be quizzed on your results.
#  You will extract and share historical data from a web page using the BeautifulSoup library.

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# 1. Extracting data using BeautifulSoup
#
#     <ul>
#     <li> Download the web page Using Requests Library </li>
#     <li> Parse HTML on a web page using BeautifulSoup </li>
#     <li> Extract data and duild a data frame </li>
#
#     </ul>
#
# 2. Extracting data using pandas
#
# </div>
#
# <hr>

# %%
# !pip install pandas
# !pip install requests
# !pip install bs4
# !pip install html5lib
# !pip install lxml
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in G:\Uzair\DS\Anaconda\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in G:\Uzair\DS\Anaconda\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in G:\Uzair\DS\Anaconda\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in G:\Uzair\DS\Anaconda\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in G:\Uzair\DS\Anaconda\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in G:\Uzair\DS\Anaconda\Lib\site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in G:\Uzair\DS\Anaconda\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in G:\Uzair\DS\Anaconda\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in G:\Uzair\DS\Anaconda\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in G:\Uzair\DS\Anaconda\Lib\site-packages (from requests) (2026.6.17)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in G:\Uzair\DS\Anaconda\Lib\site-packages (from bs4) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in G:\Uzair\DS\Anaconda\Lib\site-packages (from beautifulsoup4->bs4) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in G:\Uzair\DS\Anaconda\Lib\site-packages (from beautifulsoup4->bs4) (4.16.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Defaulting to user installation because normal site-packages is not writeable
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six>=1.9 in G:\Uzair\DS\Anaconda\Lib\site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in G:\Uzair\DS\Anaconda\Lib\site-packages (from html5lib) (0.5.1)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting lxml
#   Using cached lxml-6.1.3-cp314-cp314-win_amd64.whl.metadata (3.4 kB)
# Using cached lxml-6.1.3-cp314-cp314-win_amd64.whl (4.1 MB)
# Installing collected packages: lxml
# Successfully installed lxml-6.1.3
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in G:\Uzair\DS\Anaconda\Lib\site-packages (6.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in G:\Uzair\DS\Anaconda\Lib\site-packages (from plotly) (2.23.0)
# Requirement already satisfied: packaging in G:\Uzair\DS\Anaconda\Lib\site-packages (from plotly) (26.0)

# %% [markdown]
# ## Exercise

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# #### 1. Use the `requests` library to download the webpage [https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html). Save the text of the response as a variable named `html_data`.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html"

response = requests.get(url)
html_data = response.text

# %% [markdown]
# #### 2. Parse the html data using `beautiful_soup`.

# %%
soup = BeautifulSoup(html_data, "html.parser")

# %% [markdown]
# <b>Question 1:</b> What is the content of the title tag?

# %%
title_content = soup.title.text
print(title_content)
# Out:
# Amazon.com, Inc. (AMZN) Stock Historical Prices & Data - Yahoo Finance

# %% [markdown]
# #### 3. Using BeautifulSoup, extract the table with historical share prices and store it into a data frame named `amazon_data`. The data frame should have columns Date, Open, High, Low, Close, Adj Close, and Volume. Fill in each variable with the correct data from the list `col`.

# %%
amazon_data = pd.DataFrame(columns=["Date", "Open", "High", "Low", "Close", "Volume"])

for row in soup.find("tbody").find_all("tr"):
    col = row.find_all("td")
    date = col[0]
    Open = col[1]
    high = col[2]
    low = col[3]
    close = col[4]
    adj_close = col[5]
    volume = col[6]
    
    amazon_data = pd.concat([amazon_data, pd.DataFrame({"Date":[date], "Open":[Open], "High":[high], "Low":[low], "Close":[close], "Adj Close":[adj_close], "Volume":[volume]})], ignore_index=True)

# %% [markdown]
# #### 4. Print out the first five rows of the `amazon_data` data frame you created.

# %%
amazon_data.head()
# Out:
#                Date          Open          High           Low         Close  \
# 0  [[Jan 01, 2021]]  [[3,270.00]]  [[3,363.89]]  [[3,086.00]]  [[3,206.20]]
# 1  [[Dec 01, 2020]]  [[3,188.50]]  [[3,350.65]]  [[3,072.82]]  [[3,256.93]]
# 2  [[Nov 01, 2020]]  [[3,061.74]]  [[3,366.80]]  [[2,950.12]]  [[3,168.04]]
# 3  [[Oct 01, 2020]]  [[3,208.00]]  [[3,496.24]]  [[3,019.00]]  [[3,036.15]]
# 4  [[Sep 01, 2020]]  [[3,489.58]]  [[3,552.25]]  [[2,871.00]]  [[3,148.73]]
#
#             Volume     Adj Close
# 0   [[71,528,900]]  [[3,206.20]]
# 1   [[77,556,200]]  [[3,256.93]]
# 2   [[90,810,500]]  [[3,168.04]]
# 3  [[116,226,100]]  [[3,036.15]]
# 4  [[115,899,300]]  [[3,148.73]]

# %% [markdown]
# <b>Question 2:</b> What are the names of the columns in the data frame?

# %%
amazon_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='str')

# %% [markdown]
# <b>Question 3:</b> What is the `Open` of the last row of the amazon_data data frame?

# %%
amazon_data["Open"].iloc[-1].text
# Out:
# '656.29'

# %% [markdown]
# <h2>About the Author:</h2>
#
# Uzair Aslam <br>
# [LinkeIn](https://www.linkedin.com/in/uzair-aslam-016156269/)

# %% [markdown]
# <!--
#
#
#
#  ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    |       Change Description              |
# | ----------------- | ------- | ------------- | ------------------------------------- |
# |  02-05-2023       |   1.3   | Akansha yadav | Updated Lab content under maintenance |
# |  2021-06-09       | 1.2     | Lakshmi Holla |   Added URL in question 3             |
# |  2020-11-10       | 1.1     | Malika Singla |   Deleted the Optional part           |
# |  2020-08-27       | 1.0     | Malika Singla |   Added lab to GitLab                 |
#
# <hr>
#
#
#
# <p>
# --!>
